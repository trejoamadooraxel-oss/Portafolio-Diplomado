# %%
import pandas as pd
import os
import pydantic

# %%
"""|Operador | Operacion |
|suma| + |
|resta| - |
|Multiplicacion| * |
|Division| / |
|Division entera| // |
| Modulo| % |
|Potencial ** o Libreria math (pow) |
|raiz|"""

# %%
#0.8,0.5 para gato mayor igual que 0.5
#0.3 para perro menor que 0.3
#forward propagation
#back propagation = disminuir el error

entradas = [0.8,0.3,0.5]
pesos = [0.4,0.7,0.2]
sesgo = 0.1
#yp = (x1 * w1) + (x2 * w2) + (x3 * w3)

yp = (entradas[0] * pesos[0]) + (entradas[1] * pesos[1]) + (entradas[2] * pesos[2]) + sesgo
print(f'yp: {yp}')
if yp >= 0.5:
    print("gato")
else:
    print('perro')
# Out:
# yp: 0.73
# gato

# %%
# Realizar una neurona artificial de 4 entradas y la clasificacion 3 "gato", "perro", "ave" donde la probabilidad de gato
# sea ‹0.15 , La probabilidad de perro sea › 0.68, la propabilidad de 0.15 a 0.68 sea de "ave" x1, x2, x3 y x4 valdran
# 0.5,0. 67,0.85, d.32 respectivamente y los pesos w1,w2, w3,w4 seran 0.14,0.22,0.07,0.10 respectivamente y el bias(sesgo) valdra 0.
